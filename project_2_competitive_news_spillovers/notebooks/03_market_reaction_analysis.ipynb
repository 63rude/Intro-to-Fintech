# %% [markdown]
# # 03 Market Reaction Analysis
#
# Purpose:
# - Build the event panel that links labeled news to competitor outcomes.
# - Produce descriptive tables and simple event-study style comparisons.
# - Test whether contagion versus competition labels line up with rival stock reactions.
#
# Suggested sections:
# 1. Load labeled news and price data.
# 2. Construct competitor outcome variables.
# 3. Summarize reactions by label bucket.
# 4. Draft figures and interpret results.
