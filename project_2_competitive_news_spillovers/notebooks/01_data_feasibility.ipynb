# %% [markdown]
# # 01 Data Feasibility
#
# Purpose:
# - Check whether candidate news APIs provide usable text, dates, and ticker mapping.
# - Confirm that daily price and volume data are available for the same firms.
# - Decide on a realistic pilot sample before scaling.
#
# Suggested sections:
# 1. Define a small pilot universe.
# 2. Probe news coverage by source.
# 3. Probe price coverage with yfinance.
# 4. Document rate limits and gaps.
