# %% [markdown]
# # 02 LLM Classification Test
#
# Purpose:
# - Run a small pilot sample through the draft news-classification prompt.
# - Check whether labels capture competitor implications rather than headline tone alone.
# - Revise prompt wording for ambiguous cases.
#
# Suggested sections:
# 1. Load pilot news records.
# 2. Apply the prompt to a limited sample.
# 3. Review outputs manually.
# 4. Log prompt revisions.
